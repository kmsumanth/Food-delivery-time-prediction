# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the dataset 

df=pd.read_csv("data/zomato.csv")

# %%
#seeing the top 5 rows

df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
#seeing the last 5 rows

df.tail()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 45579  0x7c09      JAPRES04DEL01                 30.0  \
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 45579                      4.8            26.902328             75.794257  \
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 45579                   26.912328                    75.804257  24-03-2022  \
# ...

# %%
# seeing the random 5 samples

df.sample(5)
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 42734  0xb77e     PUNERES20DEL02                 30.0  \
# 1971   0xa89a     INDORES19DEL01                 33.0
# 6130   0xe25d      ALHRES17DEL01                 36.0
# 12277  0xd68f      BHPRES17DEL02                 30.0
# 26487  0xcc86      KNPRES11DEL01                 35.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 42734                      4.5            18.592718             73.773572  \
# 1971                       4.8            22.745536             75.893106
# 6130                       4.9            25.452350             81.841889
# 12277                      4.8            23.218998             77.373573
# 26487                      4.3            26.474986             80.342796
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 42734                   18.612718                    73.793572  01-03-2022  \
# ...

# %%
# no of rows and columns present in the dataset

df.shape
# Out:
# (45584, 20)

# %%
# seeing the info of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
# to see the total  number of missing values

df.isnull().sum().sum()
# Out:
# 9131

# %%
# to see column wise missing values

df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
# data type of each features

df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
# we can observe that the features ID and Delivery_person_ID is useless 
# so we can drop them

df=df.drop(labels=['ID','Delivery_person_ID'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
# in this dataset we have latitude and longitude of restaurant and delivery location 
#we can use them and calculate distance between the restaurant and delivery location

import geopy.distance

def calculate_distance_between_restaurant_and_delivery_location(res_la,res_long,del_la,del_long):
    '''
    calculate the distance between restaurant and delivery location using coordinates

    '''
    return geopy.distance.geodesic((abs(res_la),abs(res_long)),(abs(del_la),abs(del_long))).km

# %%
df['distance in(km)']=df[['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude']].apply(lambda x:calculate_distance_between_restaurant_and_delivery_location(*x),axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
# we can see that we have  created new feature distance using the features Restaurant_latitude ,Restaurant_longitude,Delivery_location_latitude	,Delivery_location_longitude
# Now we can drop Restaurant_latitude	Restaurant_longitude	Delivery_location_latitude	Delivery_location_longitude these columns since distance is already calculated using them

# %%
df=df.drop(labels=['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Order_Date Time_Orderd
# 0                 36.0                      4.2  12-02-2022       21:55  \
# 1                 21.0                      4.7  13-02-2022       14:55
# 2                 23.0                      4.7  04-03-2022       17:30
# 3                 34.0                      4.3  13-02-2022       09:20
# 4                 24.0                      4.7  14-02-2022       19:50
#
#   Time_Order_picked Weather_conditions Road_traffic_density
# 0             22:10                Fog                  Jam  \
# 1             15:05             Stormy                 High
# 2             17:40         Sandstorms               Medium
# 3             09:30         Sandstorms                  Low
# 4             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries
# 0                  2         Snack      motorcycle                  3.0  \
# ...

# %%
df['Time_Orderd'].dtype
# Out:
# dtype('O')

# %%
def prep_time(df):
    
    '''
    Convert order time and order_picked times to datetime objects and extract time information and calculate preperation time
    '''

    df["order_datetime"] = pd.to_datetime(df["Order_Date"] + ' ' + df["Time_Orderd"],format='mixed',errors='coerce', dayfirst=True)
    df["picked_datetime"] = pd.to_datetime(df["Order_Date"] + ' ' + df["Time_Order_picked"],format='mixed',errors='coerce', dayfirst=True)

    df = df.drop(["Order_Date", "Time_Orderd", "Time_Order_picked"], axis=1)

    df["ordered_hour"] = df["order_datetime"].apply(lambda x: x.hour)
    df["ordered_min"] = df["order_datetime"].apply(lambda x: x.minute)

    df["picked_hour"] = df["picked_datetime"].apply(lambda x: x.hour)
    df["picked_min"] = df["picked_datetime"].apply(lambda x: x.minute)

    def calc_prep_time(ord_hour, ord_min, pc_hour, pc_min):
        
        '''
        Calculating order preperation times. Careful about:
            - orders given before hour 24 and picked after hour 24
            - order preperation times bigger than 60 minutes
        '''
        
        if ord_hour == pc_hour:
            if pc_min > ord_min:
                return pc_min - ord_min
            else:
                return 0

        else:
            return 60 - ord_min + pc_min

    df["prep_min"] = df.iloc[:,-4:].apply(lambda x: calc_prep_time(*x), axis=1)
    
    return df

df = prep_time(df)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)
# ...

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age         1854
# Delivery_person_Ratings     1908
# Weather_conditions           616
# Road_traffic_density         601
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries          993
# Festival                     228
# City                        1200
# Time_taken (min)               0
# distance in(km)                0
# order_datetime              5799
# picked_datetime             5007
# ordered_hour                5799
# ordered_min                 5799
# picked_hour                 5007
# picked_min                  5007
# prep_min                   10177
# dtype: int64

# %%
df_copy=df.copy()

# %%
df_copy.shape
# Out:
# (45584, 19)

# %%
df_copy=df_copy.dropna(axis=0)

# %%
df_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)
# ...

# %%
df_copy.shape
# Out:
# (33600, 19)

# %%
df_copy.isnull().sum()
# Out:
# Delivery_person_Age        0
# Delivery_person_Ratings    0
# Weather_conditions         0
# Road_traffic_density       0
# Vehicle_condition          0
# Type_of_order              0
# Type_of_vehicle            0
# multiple_deliveries        0
# Festival                   0
# City                       0
# Time_taken (min)           0
# distance in(km)            0
# order_datetime             0
# picked_datetime            0
# ordered_hour               0
# ordered_min                0
# picked_hour                0
# picked_min                 0
# prep_min                   0
# dtype: int64

# %%
#Visualize Data

# %%
df_copy1=df_copy.copy()

# %%
df_copy1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)
# ...

# %%
df_copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33600 entries, 0 to 45583
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_Age      33600 non-null  float64
#  1   Delivery_person_Ratings  33600 non-null  float64
#  2   Weather_conditions       33600 non-null  object
#  3   Road_traffic_density     33600 non-null  object
#  4   Vehicle_condition        33600 non-null  int64
#  5   Type_of_order            33600 non-null  object
#  6   Type_of_vehicle          33600 non-null  object
#  7   multiple_deliveries      33600 non-null  float64
#  8   Festival                 33600 non-null  object
#  9   City                     33600 non-null  object
#  10  Time_taken (min)         33600 non-null  int64
#  11  distance in(km)          33600 non-null  float64
#  12  order_datetime           33600 non-null  datetime64[ns]
# ...

# %%
#Bivariate Analysis

# %%
numerical_columns=df_copy1.columns[df.dtypes!="object"]
categorical_columns=df_copy1.columns[df.dtypes=="object"]
target = "Time_taken (min)"
print("Numerical columns ",numerical_columns)
print("Categorical columns ",categorical_columns)
# Out:
# Numerical columns  Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)', 'distance in(km)',
#        'order_datetime', 'picked_datetime', 'ordered_hour', 'ordered_min',
#        'picked_hour', 'picked_min', 'prep_min'],
#       dtype='object')
# Categorical columns  Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
sns.kdeplot(data=df_copy, x=target, shade=True, color="crimson", lw=2)
plt.show()
# Out:
# C:\Users\kms\AppData\Local\Temp\ipykernel_15196\515433990.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df_copy, x=target, shade=True, color="crimson", lw=2)

# %%
df_copy1[numerical_features].hist(layout=(2,3), figsize=(10,6))
plt.show()

# %%
plt.figure(figsize=(8,4))

corr_matrix = df_copy1[numerical_features+[target]].corr()
matrix = np.triu(corr_matrix)

sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1, cmap="Blues")
plt.title("heatmap")
plt.show()

# %%
plt.figure(figsize=(8,4))

corr_matrix = df_copy1[numerical_features+[target]].corr()
lower_matrix = np.triu(corr_matrix) #Print only lower correlation matrix since the correlation matrix is symmetric from diagonal.

sns.heatmap(corr_matrix, mask=lower_matrix, annot=True, vmin=-1, vmax=1, cmap="plasma")
plt.title("heatmap")
plt.show()

# %%
len(categorical_columns)
# Out:
# 6

# %%
# Out:
# 15
